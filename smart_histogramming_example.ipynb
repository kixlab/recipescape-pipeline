# %%
import numpy
import json
import pprint as pp

from retrieve_recipes import *
#from im2recipe_w2v_weight import *

recipes = get_all_recipes('potatosalad') #list

# %%
ids=[]
for recipe in recipes:
    ids.append(recipe['id'])

len(set(ids)) #how many recipes - determined by distict IDs
# Out:
# 34

# %%
recipe_inst = []
recipe_lengths = []

for curr_id in ids:
    for recipe in recipes:
        if recipe['id'] == curr_id:
            recipe_inst+=(recipe['tree'])
    recipe_lengths.append(len(recipe_inst))
    recipe_inst=[]

#calculate the numer of steps for each recipe --> recipe_lengths

# %%
print(len(recipe_lengths))
# Out:
# 35

# %%
import statistics as st
from collections import Counter

data = Counter(recipe_lengths)

try:
    bin_size=st.mode(recipe_lengths)
    #will throw exception if there's more than one mode
except Exception: 
    #then use collections to get modes
    bin_size=data.most_common(2)[0][0]  # Returns two highest occurring item

#bin_size contains the # of bins we want to use

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.asarray(recipe_lengths)

plt.hist(x, normed=True, bins=bin_size)
plt.title("Histogram with mode bins")
plt.ylabel('recipeTrend');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.asarray(recipe_lengths)

plt.hist(x, normed=True, bins='doane')
plt.title("Histogram with 'doane' bins")
plt.ylabel('recipeTrend');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.asarray(recipe_lengths)

plt.hist(x, normed=True, bins='fd')
plt.title("Histogram with 'fd' bins")
plt.ylabel('recipeTrend');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.asarray(recipe_lengths)

plt.hist(x, normed=True, bins='auto')
plt.title("Histogram with 'auto' bins")
plt.ylabel('recipeTrend');
